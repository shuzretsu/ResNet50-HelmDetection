# %%
import urllib.request
import os

# Create the 'face_detector' directory if it doesn't exist
os.makedirs('face_detector', exist_ok=True)

# URL for deploy.prototxt
deploy_url = 'https://raw.githubusercontent.com/opencv/opencv/master/samples/dnn/face_detector/deploy.prototxt'
urllib.request.urlretrieve(deploy_url, 'face_detector/deploy.prototxt')

# URL for res10_300x300_ssd_iter_140000.caffemodel
model_url = 'https://github.com/opencv/opencv_3rdparty/raw/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel'
urllib.request.urlretrieve(model_url, 'face_detector/res10_300x300_ssd_iter_140000.caffemodel')
# Out:
# ('face_detector/res10_300x300_ssd_iter_140000.caffemodel',
#  <http.client.HTTPMessage at 0x2349a26ed30>)

# %%
# Import necessary libraries
import numpy as np
import cv2 as cv
from cv2 import dnn

# Set parameters
inWidth = 300
inHeight = 300
confThreshold = 0.5

prototxt = 'face_detector/deploy.prototxt'
caffemodel = 'face_detector/res10_300x300_ssd_iter_140000.caffemodel'

# Load pre-trained model
net = dnn.readNetFromCaffe(prototxt, caffemodel)

# Open webcam
cap = cv.VideoCapture(0)

while True:
    # Read frame from webcam
    ret, frame = cap.read()
    cols = frame.shape[1]
    rows = frame.shape[0]

    # Perform face detection
    net.setInput(dnn.blobFromImage(frame, 1.0, (inWidth, inHeight), (104.0, 177.0, 123.0), False, False))
    detections = net.forward()

    perf_stats = net.getPerfProfile()

    print('Inference time, ms: %.2f' % (perf_stats[0] / cv.getTickFrequency() * 1000))

    # Process and display the detections
    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]
        if confidence > confThreshold:
            xLeftBottom = int(detections[0, 0, i, 3] * cols)
            yLeftBottom = int(detections[0, 0, i, 4] * rows)
            xRightTop = int(detections[0, 0, i, 5] * cols)
            yRightTop = int(detections[0, 0, i, 6] * rows)

            cv.rectangle(frame, (xLeftBottom, yLeftBottom), (xRightTop, yRightTop),
                         (0, 255, 0))
            label = "face: %.4f" % confidence
            labelSize, baseLine = cv.getTextSize(label, cv.FONT_HERSHEY_SIMPLEX, 0.5, 1)

            cv.rectangle(frame, (xLeftBottom, yLeftBottom - labelSize[1]),
                                (xLeftBottom + labelSize[0], yLeftBottom + baseLine),
                                (255, 255, 255), cv.FILLED)
            cv.putText(frame, label, (xLeftBottom, yLeftBottom),
                       cv.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0))

    # Display the frame with detections
    cv.imshow("detections", frame)
    
    # Break the loop if any key is pressed
    if cv.waitKey(1) != -1:
        break

# Release resources
cap.release()
cv.destroyAllWindows()

model.save("model.h5")
 
print("Saved model to disk")
# Out:
# Inference time, ms: 48.78
# Inference time, ms: 31.87
# Inference time, ms: 33.67
# Inference time, ms: 29.02
# Inference time, ms: 42.03
# Inference time, ms: 28.25
# Inference time, ms: 28.96
# Inference time, ms: 25.53
# Inference time, ms: 28.47
# Inference time, ms: 29.00
# Inference time, ms: 26.81
# Inference time, ms: 27.91
# Inference time, ms: 27.52
# Inference time, ms: 28.51
# Inference time, ms: 27.68
# Inference time, ms: 25.71
# Inference time, ms: 27.15
# Inference time, ms: 29.02
# Inference time, ms: 27.59
# Inference time, ms: 30.06
# Inference time, ms: 29.25
# Inference time, ms: 26.74
# Inference time, ms: 26.63
# Inference time, ms: 26.37
# Inference time, ms: 36.22
# Inference time, ms: 25.79
# Inference time, ms: 27.39
# Inference time, ms: 30.05
# Inference time, ms: 25.47
# Inference time, ms: 33.66
# Inference time, ms: 25.66
# Inference time, ms: 26.60
# Inference time, ms: 27.41
# Inference time, ms: 26.60
# Inference time, ms: 31.72
# Inference time, ms: 27.75
# Inference time, ms: 28.02
# Inference time, ms: 28.21
# Inference time, ms: 26.05
# Inference time, ms: 29.93
# Inference time, ms: 28.32
# Inference time, ms: 28.15
# Inference time, ms: 25.53
# Inference time, ms: 30.11
# Inference time, ms: 27.95
# Inference time, ms: 26.97
# Inference time, ms: 26.64
# Inference time, ms: 27.53
# Inference time, ms: 28.60
# Inference time, ms: 33.76
# Inference time, ms: 31.14
# Inference time, ms: 29.59
# Inference time, ms: 34.41
# Inference time, ms: 32.47
# Inference time, ms: 32.51
# Inference time, ms: 33.18
# Inference time, ms: 34.63
# Inference time, ms: 30.90
# Inference time, ms: 32.21
# Inference time, ms: 34.36
# Inference time, ms: 27.47
# Inference time, ms: 29.26
# Inference time, ms: 27.16
# Inference time, ms: 29.62
# Inference time, ms: 28.47
# Inference time, ms: 28.77
# Inference time, ms: 27.33
# Inference time, ms: 25.55
# Inference time, ms: 31.43
# Inference time, ms: 29.43
# Inference time, ms: 27.63
# Inference time, ms: 28.89
# Inference time, ms: 27.38
# Inference time, ms: 28.53
# Inference time, ms: 31.50
# Inference time, ms: 27.81
# Inference time, ms: 24.37
# Inference time, ms: 26.54
# Inference time, ms: 29.85
# Inference time, ms: 27.57
# Inference time, ms: 29.01
# Inference time, ms: 34.42
# Inference time, ms: 26.93
# Inference time, ms: 27.29
# Inference time, ms: 26.84
# Inference time, ms: 30.35
# Inference time, ms: 27.28
# Inference time, ms: 28.09
# Inference time, ms: 31.43
# Inference time, ms: 26.36
# Inference time, ms: 30.95
# Inference time, ms: 26.66
# Inference time, ms: 26.97
# Inference time, ms: 28.49
# Inference time, ms: 28.07
# Inference time, ms: 32.36
# Inference time, ms: 27.01
# Inference time, ms: 27.78
# Inference time, ms: 27.19
# Inference time, ms: 26.80
# Inference time, ms: 29.78
# Inference time, ms: 28.30
# Inference time, ms: 26.88
# Inference time, ms: 28.29
# Inference time, ms: 26.98
# Inference time, ms: 31.57
# Inference time, ms: 26.07
# Inference time, ms: 29.54
# Inference time, ms: 27.48
# Inference time, ms: 27.45
# Inference time, ms: 27.27
# Inference time, ms: 31.96
# Inference time, ms: 29.42
# Inference time, ms: 37.10
# Inference time, ms: 23.93
# Inference time, ms: 27.45
# Inference time, ms: 30.60
# Inference time, ms: 26.12
# Inference time, ms: 28.68
# Inference time, ms: 27.27
# Inference time, ms: 26.75
# Inference time, ms: 26.77
# Inference time, ms: 28.48
# Inference time, ms: 33.03
# Inference time, ms: 26.38
# Inference time, ms: 29.31
# Inference time, ms: 27.70
# Inference time, ms: 26.92
# Inference time, ms: 29.10
# Inference time, ms: 28.32
# Inference time, ms: 32.08
# Inference time, ms: 27.78
# Inference time, ms: 35.81
# Inference time, ms: 38.24
# Inference time, ms: 29.09
# Inference time, ms: 27.96
# Inference time, ms: 27.12
# Inference time, ms: 26.78
# Inference time, ms: 29.42
# Inference time, ms: 28.80
# Inference time, ms: 32.32
# Inference time, ms: 31.23
# Saved model to disk

# %% [raw]
# # code save
#
# import cv2
# import numpy as np
# from tensorflow.keras.models import load_model
# from tensorflow.keras.applications.resnet50 import preprocess_input
# from tensorflow.keras.preprocessing.image import img_to_array
# from IPython.display import display, Image
# import matplotlib.pyplot as plt
#
#
# # Load the trained model
# model = load_model('C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\helm\\helm\\model.h5')
#
# # List of image file paths
# image_paths = ['C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\helm\\helm\\dataset\\helmet_yes\\helmety18.jpg', 'C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\helm\\helm\\dataset\\helmet_no\\1.jpg']
#
# output_width, output_height = 200, 200
# # Loop through image files
# for image_path in image_paths:
#     # Read the image
#     frame = cv2.imread(image_path)
#
#     # Apply face detection (you may need to replace this with your own face detection logic)
#     # For simplicity, assuming the entire image is a face region
#     face_region = frame
#
#     # Resize the face region to match the input size expected by the model
#     face_region = cv2.resize(face_region, (224, 224), interpolation=cv2.INTER_AREA)
#
#     # Preprocess the input image
#     x = img_to_array(face_region)
#     x = np.expand_dims(x, axis=0)
#     x = preprocess_input(x)
#
#     # Make a prediction using the model
#     prediction = model.predict(x)
#
#     # Determine whether the person is wearing a helmet or not
#     if prediction < 0.04:  # Helmet not detected
#         label = "Helmet X ({:.2f}%)".format((1 - prediction[0][0]) * 100)
#         color = (0, 0, 255)
#     else:  # Helmet detected
#         label = "Helmet O ({:.2f}%)".format(prediction[0][0] * 100)
#         color = (0, 255, 0)
#
#     # Add label to the image
#     cv2.putText(frame, label, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)
#
#     # Display output in Jupyter Notebook
#     _, img_encoded = cv2.imencode('.png', frame)
#     img_bytes = img_encoded.tobytes()
#     display(Image(data=img_bytes))
#
#     # Display Helmet X or Helmet O in separate plots
#     plt.figure(figsize=(6, 6))
#
#     # Original image
#     plt.subplot(1, 2, 1)
#     plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
#     plt.title("Original Image")
#     plt.axis("off")
#
#     # Cropped face region
#     plt.subplot(1, 2, 2)
#     plt.imshow(cv2.cvtColor(face_region, cv2.COLOR_BGR2RGB))
#     plt.title(label)
#     plt.axis("off")
#
#     plt.show()
