mety277.jpg', 'helmety278.jpg', 'helmety279.jpg', 'helmety280.jpg', 'helmety281.jpg', 'helmety282.jpg', 'helmety283.jpg', 'helmety284.jpg', 'helmety285.jpg', 'helmety286.jpg', 'helmety287.jpg', 'helmety288.jpg', 'helmety289.jpg', 'helmety290.jpg', 'helmety291.jpg', 'helmety292.jpg', 'helmety293.jpg', 'helmety294.jpg', 'helmety295.jpg', 'helmety296.jpg', 'helmety297.jpg', 'helmety298.jpg', 'helmety299.jpg', 'helmety30.jpg', 'helmety300.jpg', 'helmety301.jpg', 'helmety302.jpg', 'helmety303.jpg', 'helmety304.jpg', 'helmety305.jpg', 'helmety306.jpg', 'helmety307.jpg', 'helmety308.jpg', 'helmety309.jpg', 'helmety31.jpg', 'helmety310.jpg', 'helmety311.jpg', 'helmety312.jpg', 'helmety32.jpg', 'helmety321.jpg', 'helmety34.jpg', 'helmety343.jpg', 'helmety35.jpg', 'helmety36.jpg', 'helmety37.jpg', 'helmety38.jpg', 'helmety42.jpg', 'helmety43.jpg', 'helmety44.jpg', 'helmety45.jpg', 'helmety46.jpg', 'helmety47.jpg', 'helmety48.jpg', 'helmety49.jpg', 'helmety50.jpg', 'helmety52.jpg', 'helmety54.jpg', 'helmety55.jpg', 'helmety56.jpg', 'helmet ...

# %%
import cv2
image_path = 'C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\dataset\\helmet_no\\helmetn2.jpg'
image = cv2.imread(image_path)
# Convert BGR ke RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# mendisplay gambar
plt.imshow(image_rgb)
plt.axis('off')  # mematikan label axis
plt.show()

# %%
image.shape
# Out:
# (246, 238, 3)

# %%
for i in non_list:
    print(i)
    
    # Image Path
    image_path = 'C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\dataset\\helmet_no\\' + i

    # membaca gambar
    img = cv2.imread(image_path)

    # pengecekkan gambar jika terload
    if img is not None:
        print(img.shape)
    else:
        print(f"Failed to read image: {image_path}")
# Out:
# helmetn1.jpg
# (240, 240, 3)
# helmetn10.jpg
# (238, 240, 3)
# helmetn100.jpg
# (240, 234, 3)
# helmetn101.jpg
# (240, 234, 3)
# helmetn102.jpg
# (240, 238, 3)
# helmetn103.jpg
# (240, 240, 3)
# helmetn104.jpg
# (248, 240, 3)
# helmetn105.jpg
# (236, 238, 3)
# helmetn106.jpg
# (236, 240, 3)
# helmetn107.jpg
# (236, 242, 3)
# helmetn108.jpg
# (236, 234, 3)
# helmetn109.jpg
# (238, 238, 3)
# helmetn11.jpg
# (238, 232, 3)
# helmetn110.jpg
# (232, 240, 3)
# helmetn111.jpg
# (238, 240, 3)
# helmetn112.jpg
# (238, 242, 3)
# helmetn113.jpg
# (232, 234, 3)
# helmetn114.jpg
# (240, 242, 3)
# helmetn115.jpg
# (238, 238, 3)
# helmetn116.jpg
# (236, 240, 3)
# helmetn117.jpg
# (238, 240, 3)
# helmetn118.jpg
# (236, 242, 3)
# helmetn119.jpg
# (238, 246, 3)
# helmetn12.jpg
# (238, 234, 3)
# helmetn120.jpg
# (246, 238, 3)
# helmetn121.jpg
# (242, 240, 3)
# helmetn122.jpg
# (246, 240, 3)
# helmetn123.jpg
# (242, 242, 3)
# helmetn124.jpg
# (242, 234, 3)
# helmetn125.jpg
# (240, 234, 3)
# helmetn126.jpg
# (238, 238, 3)
# helmetn13.jpg
# (246, 240, 3)
# helmetn131.jpg
# (238, 238, 3)
# helmetn132.jpg
# (238, 240, 3)
# helmetn133.jpg
# (238, 240, 3)
# helmetn134.jpg
# (238, 242, 3)
# helmetn135.jpg
# (238, 234, 3)
# helmetn136.jpg
# (240, 238, 3)
# helmetn137.jpg
# (242, 240, 3)
# helmetn138.jpg
# (242, 240, 3)
# helmetn139.jpg
# (242, 234, 3)
# helmetn14.jpg
# (234, 238, 3)
# helmetn144.jpg
# (549, 563, 3)
# helmetn145.jpg
# (1872, 1872, 3)
# helmetn146.jpg
# (239, 237, 3)
# helmetn147.jpg
# (240, 240, 3)
# helmetn148.jpg
# (373, 545, 3)
# helmetn149.jpg
# (243, 242, 3)
# helmetn15.jpg
# (234, 240, 3)
# helmetn150.jpg
# (240, 238, 3)
# helmetn151.jpg
# (1281, 1920, 3)
# helmetn152.jpg
# (1440, 1920, 3)
# helmetn157.jpg
# (563, 617, 3)
# helmetn158.jpg
# (240, 240, 3)
# helmetn159.jpg
# (801, 1200, 3)
# helmetn16.jpg
# (234, 240, 3)
# helmetn160.jpg
# (711, 799, 3)
# helmetn161.jpg
# (1350, 1080, 3)
# helmetn162.jpg
# (315, 209, 3)
# helmetn163.jpg
# (651, 503, 3)
# helmetn164.jpg
# (512, 894, 3)
# helmetn165.jpg
# (632, 630, 3)
# helmetn166.jpg
# (717, 539, 3)
# helmetn167.jpg
# (274, 194, 3)
# helmetn168.jpg
# (630, 420, 3)
# helmetn169.jpg
# (240, 242, 3)
# helmetn17.jpg
# (234, 232, 3)
# helmetn170.jpg
# (1280, 1920, 3)
# helmetn171.jpg
# (1920, 1280, 3)
# helmetn172.jpg
# (717, 725, 3)
# helmetn173.jpg
# (1280, 1920, 3)
# helmetn174.jpg
# (1293, 1920, 3)
# helmetn175.jpg
# (1272, 1920, 3)
# helmetn176.jpg
# (243, 243, 3)
# helmetn177.jpg
# (1920, 1384, 3)
# helmetn178.jpg
# (591, 476, 3)
# helmetn179.jpg
# (262, 400, 3)
# helmetn18.jpg
# (234, 234, 3)
# helmetn180.jpg
# (240, 234, 3)
# helmetn181.jpg
# (1282, 1920, 3)
# helmetn182.jpg
# (1280, 1920, 3)
# helmetn183.jpg
# (1280, 1920, 3)
# helmetn184.jpg
# (251, 201, 3)
# helmetn185.jpg
# (242, 232, 3)
# helmetn186.jpg
# (241, 238, 3)
# helmetn187.jpg
# (242, 234, 3)
# helmetn188.jpg
# (240, 238, 3)
# helmetn189.jpg
# (241, 238, 3)
# helmetn19.jpg
# (242, 238, 3)
# helmetn190.jpg
# (240, 238, 3)
# helmetn191.jpg
# (397, 375, 3)
# helmetn193.jpg
# (425, 612, 3)
# helmetn194.jpg
# (1300, 866, 3)
# helmetn195.jpg
# (1000, 1500, 3)
# helmetn196.jpg
# (866, 1300, 3)
# helmetn197.jpg
# (417, 626, 3)
# helmetn198.jpg
# (544, 540, 3)
# helmetn199.jpg
# (273, 185, 3)
# helmetn2.jpg
# (246, 238, 3)
# helmetn20.jpg
# (242, 240, 3)
# helmetn200.jpg
# (1024, 786, 3)
# helmetn201.jpg
# (417, 626, 3)
# helmetn202.jpg
# (182, 278, 3)
# helmetn203.jpg
# (523, 539, 3)
# helmetn204.jpg
# (668, 1000, 3)
# helmetn205.jpg
# (1300, 866, 3)
# helmetn206.jpg
# (183, 275, 3)
# helmetn207.jpg
# (280, 390, 3)
# helmetn208.jpg
# (183, 275, 3)
# helmetn209.jpg
# (280, 389, 3)
# helmetn21.jpg
# (240, 240, 3)
# helmetn210.jpg
# (183, 275, 3)
# helmetn211.jpg
# (750, 500, 3)
# helmetn212.jpg
# (845, 1500, 3)
# helmetn213.jpg
# (1350, 1080, 3)
# helmetn215.jpg
# (377, 600, 3)
# helmetn216.jpg
# (600, 400, 3)
# helmetn217.jpg
# (597, 480, 3)
# helmetn218.jpg
# (275, 183, 3)
# helmetn219.jpg
# (183, 275, 3)
# helmetn22.jpg
# (240, 232, 3)
# helmetn220.jpg
# (183, 275, 3)
# helmetn221.jpg
# (1243, 1600, 3)
# helmetn222.jpg
# (251, 201, 3)
# helmetn223.jpg
# (700, 466, 3)
# helmetn225.jpg
# (417, 626, 3)
# helmetn226.jpg
# (594, 540, 3)
# helmetn227.jpg
# (482, 700, 3)
# helmetn228.jpg
# (450, 800, 3)
# helmetn229.jpg
# (478, 500, 3)
# helmetn23.jpg
# (240, 234, 3)
# helmetn230.jpg
# (252, 200, 3)
# helmetn231.jpg
# (583, 530, 3)
# helmetn232.jpg
# (755, 520, 3)
# helmetn233.jpg
# (769, 600, 3)
# helmetn234.jpg
# (435, 688, 3)
# helmetn235.jpg
# (866, 1300, 3)
# helmetn236.jpg
# (750, 500, 3)
# helmetn237.jpg
# (251, 201, 3)
# helmetn238.jpg
# (225, 225, 3)
# helmetn239.jpg
# (183, 275, 3)
# helmetn24.jpg
# (246, 240, 3)
# helmetn240.jpg
# (262, 192, 3)
# helmetn241.jpg
# (932, 746, 3)
# helmetn242.jpg
# (264, 191, 3)
# helmetn243.jpg
# (538, 960, 3)
# helmetn245.jpg
# (1067, 800, 3)
# helmetn246.jpg
# (588, 782, 3)
# helmetn247.jpg
# (675, 675, 3)
# helmetn248.jpg
# (262, 192, 3)
# helmetn249.jpg
# (500, 500, 3)
# helmetn25.jpg
# (238, 238, 3)
# helmetn250.jpg
# (800, 800, 3)
# helmetn251.jpg
# (259, 195, 3)
# helmetn253.jpg
# (717, 778, 3)
# helmetn254.jpg
# (800, 1200, 3)
# helmetn255.jpg
# (599, 600, 3)
# helmetn256.jpg
# (225, 225, 3)
# helmetn257.jpg
# (224, 224, 3)
# helmetn258.jpg
# (360, 360, 3)
# helmetn259.jpg
# (225, 225, 3)
# helmetn26.jpg
# (238, 240, 3)
# helmetn260.jpg
# (1000, 860, 3)
# helmetn261.jpg
# (199, 253, 3)
# helmetn262.jpg
# (152, 331, 3)
# helmetn263.jpg
# (700, 700, 3)
# helmetn264.jpg
# (540, 540, 3)
# helmetn265.jpg
# (242, 208, 3)
# helmetn266.jpg
# (800, 800, 3)
# helmetn267.jpg
# (500, 500, 3)
# helmetn268.jpg
# (540, 417, 3)
# helmetn269.jpg
# (275, 183, 3)
# helmetn27.jpg
# (238, 240, 3)
# helmetn270.jpg
# (300, 500, 3)
# helmetn272.jpg
# (700, 700, 3)
# helmetn273.jpg
# (215, 234, 3)
# helmetn274.jpg
# (513, 773, 3)
# helmetn275.jpg
# (600, 480, 3)
# helmetn276.jpg
# (320, 640, 3)
# helmetn277.jpg
# (700, 525, 3)
# helmetn278.jpg
# (770, 770, 3)
# helmetn279.jpg
# (647, 970, 3)
# helmetn28.jpg
# (238, 232, 3)
# helmetn29.jpg
# (238, 234, 3)
# helmetn3.jpg
# (241, 238, 3)
# helmetn30.jpg
# (236, 238, 3)
# helmetn31.jpg
# (236, 240, 3)
# helmetn32.jpg
# (234, 240, 3)
# helmetn33.jpg
# (234, 232, 3)
# helmetn34.jpg
# (234, 234, 3)
# helmetn35.jpg
# (246, 232, 3)
# helmetn36.jpg
# (236, 240, 3)
# helmetn37.jpg
# (236, 232, 3)
# helmetn38.jpg
# (234, 238, 3)
# helmetn39.jpg
# (234, 240, 3)
# helmetn4.jpg
# (234, 240, 3)
# helmetn40.jpg
# (234, 234, 3)
# helmetn41.jpg
# (236, 240, 3)
# helmetn42.jpg
# (234, 238, 3)
# helmetn43.jpg
# (234, 240, 3)
# helmetn44.jpg
# (234, 232, 3)
# helmetn45.jpg
# (234, 234, 3)
# helmetn46.jpg
# (236, 234, 3)
# helmetn47.jpg
# (236, 238, 3)
# helmetn48.jpg
# (236, 232, 3)
# helmetn49.jpg
# (232, 240, 3)
# helmetn5.jpg
# (239, 238, 3)
# helmetn50.jpg
# (232, 240, 3)
# helmetn51.jpg
# (232, 234, 3)
# helmetn52.jpg
# (244, 240, 3)
# helmetn53.jpg
# (234, 238, 3)
# helmetn54.jpg
# (234, 240, 3)
# helmetn55.jpg
# (234, 232, 3)
# helmetn56.jpg
# (234, 234, 3)
# helmetn57.jpg
# (240, 238, 3)
# helmetn58.jpg
# (240, 240, 3)
# helmetn59.jpg
# (240, 232, 3)
# helmetn6.jpg
# (234, 232, 3)
# helmetn60.jpg
# (240, 234, 3)
# helmetn61.jpg
# (238, 238, 3)
# helmetn62.jpg
# (238, 240, 3)
# helmetn63.jpg
# (242, 238, 3)
# helmetn64.jpg
# (242, 240, 3)
# helmetn65.jpg
# (242, 240, 3)
# helmetn66.jpg
# (238, 232, 3)
# helmetn67.jpg
# (242, 234, 3)
# helmetn68.jpg
# (240, 240, 3)
# helmetn69.jpg
# (242, 238, 3)
# helmetn7.jpg
# (234, 234, 3)
# helmetn70.jpg
# (238, 240, 3)
# helmetn71.jpg
# (242, 240, 3)
# helmetn72.jpg
# (238, 232, 3)
# helmetn73.jpg
# (238, 234, 3)
# helmetn74.jpg
# (236, 238, 3)
# helmetn75.jpg
# (232, 240, 3)
# helmetn76.jpg
# (236, 240, 3)
# helmetn77.jpg
# (232, 232, 3)
# helmetn78.jpg
# (236, 234, 3)
# helmetn79.jpg
# (240, 240, 3)
# helmetn8.jpg
# (238, 238, 3)
# helmetn80.jpg
# (238, 238, 3)
# helmetn81.jpg
# (240, 240, 3)
# helmetn82.jpg
# (238, 240, 3)
# helmetn83.jpg
# (238, 232, 3)
# helmetn84.jpg
# (238, 234, 3)
# helmetn85.jpg
# (242, 238, 3)
# helmetn86.jpg
# (242, 240, 3)
# helmetn87.jpg
# (242, 240, 3)
# helmetn88.jpg
# (238, 232, 3)
# helmetn89.jpg
# (242, 234, 3)
# helmetn9.jpg
# (238, 240, 3)
# helmetn90.jpg
# (240, 242, 3)
# helmetn91.jpg
# (238, 238, 3)
# helmetn92.jpg
# (234, 240, 3)
# helmetn93.jpg
# (238, 240, 3)
# helmetn94.jpg
# (238, 232, 3)
# helmetn95.jpg
# (234, 234, 3)
# helmetn96.jpg
# (240, 238, 3)
# helmetn97.jpg
# (240, 240, 3)
# helmetn98.jpg
# (240, 240, 3)
# helmetn99.jpg
# (240, 232, 3)

# %%
for j in yes_list:
    print(j)

    image_path = 'C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\dataset\\helmet_yes\\' + j

    img = cv2.imread(image_path)

    if img is not None:
        print(img.shape)
    else:
        print(f"Failed to read image: {image_path}")
# Out:
# helmety100.jpg
# (192, 262, 3)
# helmety101.jpg
# (507, 768, 3)
# helmety102.jpg
# (198, 255, 3)
# helmety103.jpg
# (1024, 768, 3)
# helmety104.jpg
# (168, 300, 3)
# helmety105.jpg
# (168, 300, 3)
# helmety106.jpg
# (284, 177, 3)
# helmety114.jpg
# (225, 225, 3)
# helmety115.jpg
# (168, 300, 3)
# helmety123.jpg
# (183, 275, 3)
# helmety124.jpg
# (720, 1280, 3)
# helmety125.jpg
# (162, 311, 3)
# helmety126.jpg
# (150, 335, 3)
# helmety127.jpg
# (275, 183, 3)
# helmety128.jpg
# (194, 259, 3)
# helmety129.jpg
# (181, 278, 3)
# helmety130.jpg
# (194, 259, 3)
# helmety131.jpg
# (183, 275, 3)
# helmety132.jpg
# (282, 179, 3)
# helmety133.jpg
# (180, 280, 3)
# helmety134.jpg
# (190, 265, 3)
# helmety135.jpg
# (201, 251, 3)
# helmety136.jpg
# (192, 263, 3)
# helmety137.jpg
# (159, 318, 3)
# helmety138.jpg
# (191, 264, 3)
# helmety139.jpg
# (183, 275, 3)
# helmety140.jpg
# (183, 275, 3)
# helmety141.jpg
# (184, 274, 3)
# helmety142.jpg
# (168, 300, 3)
# helmety143.jpg
# (252, 200, 3)
# helmety144.jpg
# (183, 275, 3)
# helmety145.jpg
# (183, 275, 3)
# helmety146.jpg
# (223, 226, 3)
# helmety147.jpg
# (194, 259, 3)
# helmety148.jpg
# (234, 323, 3)
# helmety149.jpg
# (540, 347, 3)
# helmety150.jpg
# (234, 193, 3)
# helmety151.jpg
# (447, 640, 3)
# helmety152.jpg
# (371, 640, 3)
# helmety153.jpg
# (540, 347, 3)
# helmety154.jpg
# (500, 640, 3)
:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\dataset\\helmet_no\\' + i
    img = cv2.imread(img_path)
    
    if img is not None:
        h.append(img.shape[0])
        w.append(img.shape[1])
    else:
        print(f"Failed to read image: {img_path}")

for j in yes_list:
    img_path = 'C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\dataset\\helmet_yes\\' + j
    img = cv2.imread(img_path)
    
    if img is not None:
        h.append(img.shape[0])
        w.append(img.shape[1])
    else:
        print(f"Failed to read image: {img_path}")

# %%
import tensorflow as tf
import keras
from tensorflow.keras.utils import img_to_array
from tensorflow.keras.utils import load_img
from PIL import Image 

img_w, img_h = 140, 180
images = [] #Data 
labels = [] #Label 

for i in non_list:
    image = load_img('C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\dataset\\helmet_no\\' + i, target_size=(img_w, img_h))
    image = img_to_array(image)
    images.append(image)
    labels.append(0)#tidak pakai helm > X
    
for j in yes_list:
    image = load_img('C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\dataset\\helmet_yes\\' + j, target_size=(img_w, img_h))
    image = img_to_array(image)
    images.append(image)
    labels.append(1)# pakai helm > O

images[0].shape
images[1].shape
# Out:
# C:\Users\relax\miniconda3\envs\LatihanCV\lib\site-packages\PIL\Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# (140, 180, 3)

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
 

    
path_dir1 = 'C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\dataset\\helmet_no\\'
path_dir2 = 'C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\dataset\\helmet_yes\\'
 
file_list1 = os.listdir(path_dir1)
file_list2 = os.listdir(path_dir2)
 
file_list1_num = len(file_list1)
file_list2_num = len(file_list2)
 
file_num = file_list1_num + file_list2_num
 
#Pemrosesan gambar awal 
num = 0;
all_img = np.float32(np.zeros((file_num, 224, 224, 3))) 
all_label = np.float64(np.zeros((file_num, 1)))
 
for img_name in file_list1:
    img_path = path_dir1+img_name
    img = load_img(img_path, target_size=(224, 224))
    
    x = img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    all_img[num, :, :, :] = x
    
    all_label[num] = 0 # tidak pakai helm
    num = num + 1

for img_name in file_list2:
    img_path = path_dir2+img_name
    img = load_img(img_path, target_size=(224, 224))
    
    x = img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    all_img[num, :, :, :] = x
    
    all_label[num] = 1 # pakai helm
    num = num + 1
 
 
# mengacak kumpulan data (untuk memastikan pelatihan yang tepat)
n_elem = all_label.shape[0]
indices = np.random.choice(n_elem, size=n_elem, replace=False)
 
all_label = all_label[indices]
all_img = all_img[indices]
 
# memisahkan set pelatihan dan data test
num_train = int(np.round(all_label.shape[0]*0.8))
num_test = int(np.round(all_label.shape[0]*0.2))
 
train_img = all_img[0:num_train, :, :, :]
test_img = all_img[num_train:, :, :, :] 
 
train_label = all_label[0:num_train]
test_label = all_label[num_train:]
 
 
 
# membuat model dasar yang telah dilatih
IMG_SHAPE = (224, 224, 3)
 
base_model = ResNet50(input_shape=IMG_SHAPE, weights='imagenet', include_top=False)
base_model.trainable = False
base_model.summary()
print("Number of layers in the base model: ", len(base_model.layers))
 
flatten_layer = Flatten()
dense_layer1 = Dense(128, activation='relu')
bn_layer1 = BatchNormalization()
dense_layer2 = Dense(1, activation=tf.nn.sigmoid)
 
model = Sequential([
        base_model,
        flatten_layer,
        dense_layer1,
        bn_layer1,
        dense_layer2,
        ])

base_learning_rate = 0.001
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
    loss='binary_crossentropy',
    metrics=['accuracy'])
model.summary()
 
history = model.fit(train_img, train_label, epochs=10, batch_size=16, validation_data = (test_img, test_label))
 
# save model
model.save("model.h5")
 
print("Saved model to disk")
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 0
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________
# Number of layers in the base model:  175
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten_1 (Flatten)         (None, 100352)            0
#
#  dense_2 (Dense)             (None, 128)               12845184
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 36,433,537
# Trainable params: 12,845,569
# Non-trainable params: 23,587,968
# _________________________________________________________________
# Epoch 1/10
# 27/27 [==============================] - 36s 1s/step - loss: 0.2673 - accuracy: 0.9100 - val_loss: 0.2470 - val_accuracy: 0.9429
# Epoch 2/10
# 27/27 [==============================] - 29s 1s/step - loss: 0.0510 - accuracy: 0.9834 - val_loss: 0.1064 - val_accuracy: 0.9619
# Epoch 3/10
# 27/27 [==============================] - 29s 1s/step - loss: 0.0096 - accuracy: 0.9976 - val_loss: 0.0975 - val_accuracy: 0.9619
# Epoch 4/10
# 27/27 [==============================] - 30s 1s/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 0.9619
# Epoch 5/10
# 27/27 [==============================] - 30s 1s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0991 - val_accuracy: 0.9619
# Epoch 6/10
# 27/27 [==============================] - 30s 1s/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9619
# Epoch 7/10
# 27/27 [==============================] - 32s 1s/step - loss: 0.0052 - accuracy: 0.9976 - val_loss: 0.1082 - val_accuracy: 0.9619
# Epoch 8/10
# 27/27 [==============================] - 37s 1s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9619
# Epoch 9/10
# 27/27 [==============================] - 32s 1s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9619
# Epoch 10/10
# 27/27 [==============================] - 32s 1s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1196 - val_accuracy: 0.9619
# Saved model to disk

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'go', label='Training Loss')
plt.plot(epochs, val_loss, 'g', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import seaborn as sns

# 'features.npy' dan 'labels.npy' file yang berisi fitur dan label yang diekstraksi
features = np.load('features.npy')
labels = np.load('labels.npy')

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# inisialisasi KNN classifier
knn_classifier = KNeighborsClassifier(n_neighbors=3)
knn_classifier.fit(X_train, y_train)

#prediksi pada test
y_pred = knn_classifier.predict(X_test)

# Evaluasi akurasi dan hasil
class_mapping = {}

base_path_no = 'Dataset\\helmet_no'
base_path_yes = 'Dataset\\helmet_yes'

# menetapkan label numerik ke kelas 'helm_no'
class_mapping[base_path_no] = np.unique(y_test)[0]
# menetapkan label numerik ke kelas 'helm_no'
class_mapping[base_path_yes] = np.unique(y_test)[1]
print(class_mapping)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
sns.countplot(x=y_test)
plt.title("Count Plot of Numeric Labels")
plt.show()
# Out:
# {'Dataset\\helmet_no': 0, 'Dataset\\helmet_yes': 1}
# Accuracy: 0.9813084112149533

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

# Plotting accuracy
plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')

# Plotting loss
plt.plot(epochs, loss, 'go', label='Training Loss')
plt.plot(epochs, val_loss, 'g', label='Validation Loss')

plt.title('Training and Validation Metrics')
plt.xlabel('Epochs')
plt.legend()

plt.show()

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from IPython.display import display, Image
import matplotlib.pyplot as plt
import os
import random

# Loadidng model
model = load_model('C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\model.h5')

helmet_yes_path = 'C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\dataset\\helmet_yes\\'
helmet_no_path = 'C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\dataset\\helmet_no\\'

helmet_yes_list = os.listdir(helmet_yes_path)
helmet_no_list = os.listdir(helmet_no_path)

# Random select image dari setiap kategori
helmet_yes_image = cv2.imread(os.path.join(helmet_yes_path, random.choice(helmet_yes_list)))
helmet_no_image = cv2.imread(os.path.join(helmet_no_path, random.choice(helmet_no_list)))

# Loop dari gambar yang dipilih
for frame in [helmet_yes_image, helmet_no_image]:
    # Resize the face region to match the input size expected by the model
    face_region = cv2.resize(frame, (224, 224), interpolation=cv2.INTER_AREA)

    # Preprocess gambar input
    x = img_to_array(face_region)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)

    # predict model
    prediction = model.predict(x)

    #Helmet X atau O
    if prediction < 0.04:  # Helmet not detected
        label = "Helmet X ({:.2f}%)".format((1 - prediction[0][0]) * 100)
        color = (0, 0, 255)
    else:  # Helmet detected
        label = "Helmet O ({:.2f}%)".format(prediction[0][0] * 100)
        color = (0, 255, 0)

    # label GAMBAR
    cv2.putText(frame, label, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)
    _, img_encoded = cv2.imencode('.png', frame)
    img_bytes = img_encoded.tobytes()
    display(Image(data=img_bytes))
    plt.figure(figsize=(6, 6))

    # gambar original
    plt.subplot(1, 2, 1)
    plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    plt.title("Original Image")
    plt.axis("off")
    plt.subplot(1, 2, 2)
    plt.imshow(cv2.cvtColor(face_region, cv2.COLOR_BGR2RGB))
    plt.title(label)
    plt.axis("off")

    plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 141ms/step

# %%
# menyimpan seluruh model ke satu file H5
model.save('C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\model.h5')
print(model.save)
# Out:
# <bound method Model.save of <keras.engine.sequential.Sequential object at 0x000002E7316DCF70>>

# %%
from tensorflow.keras.models import load_model

loaded_model = load_model('C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\model.h5')

# %%
print("Prediction:", prediction)
print("Raw Predictions:", prediction)
# Out:
# Prediction: [[0.00072099]]
# Raw Predictions: [[0.00072099]]

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# %%
import cvlib as cv
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from PIL import ImageFont, ImageDraw, Image

model = load_model('C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\model.h5')
model.summary()

# open webcam
webcam = cv2.VideoCapture(0)

if not webcam.isOpened():
    print("Could not open webcam")
    exit()

# loop frame
while webcam.isOpened():
    # membaca frame dari webcam
    status, frame = webcam.read()

    if not status:
        print("Could not read frame")
        exit()

    # deteksi wajah
    face, confidence = cv.detect_face(frame)

    # loop untuk wajah yang dideteksi
    for idx, f in enumerate(face):
        (startX, startY) = f[0], f[1]
        (endX, endY) = f[2], f[3]

        if 0 <= startX <= frame.shape[1] and 0 <= endX <= frame.shape[1] and 0 <= startY <= frame.shape[0] and 0 <= endY <= frame.shape[0]:
            face_region = frame[startY:endY, startX:endX]
            face_region1 = cv2.resize(face_region, (224, 224), interpolation=cv2.INTER_AREA)

            x = img_to_array(face_region1)
            x = np.expand_dims(x, axis=0)
            x = preprocess_input(x)

            prediction = model.predict(x)
            threshold = 0.05
            #0.02084012
            #0.01972104
            if prediction < threshold:  # pakai helm
                cv2.rectangle(frame, (startX, startY), (endX, endY), (0, 0, 255), 2)
                Y = startY - 10 if startY - 10 > 10 else startY + 10
                text = "Helmet X ({:.2f}%)".format((1 - prediction[0][0]) * 100)
                cv2.putText(frame, text, (startX, Y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

            else:  # tidak pakai helm
                cv2.rectangle(frame, (startX, startY), (endX, endY), (0, 255, 0), 2)
                Y = startY - 10 if startY - 10 > 10 else startY + 10
                text = "Helmet 0 ({:.2f}%)".format(prediction[0][0] * 100)
                cv2.putText(frame, text, (startX, Y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

    # output
    cv2.imshow("Helmet classify", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

webcam.release()
cv2.destroyAllWindows()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten_1 (Flatten)         (None, 100352)            0
#
#  dense_2 (Dense)             (None, 128)               12845184
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 36,433,537
# Trainable params: 12,845,569
# Non-trainable params: 23,587,968
# _________________________________________________________________
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 111ms/step

# %%
print("Prediction:", prediction)
print("Raw Predictions:", prediction)
#print statement untuk mencetak prediksi model
# Out:
# Prediction: [[0.02891449]]
# Raw Predictions: [[0.02891449]]

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array

    
path_dir1 = 'C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\dataset\\helmet_no\\'
path_dir2 = 'C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\dataset\\helmet_yes\\'
 
file_list1 = os.listdir(path_dir1)
file_list2 = os.listdir(path_dir2)
 
file_list1_num = len(file_list1)
file_list2_num = len(file_list2)
 
file_num = file_list1_num + file_list2_num
 
#Pemrosesan gambar awal 
num = 0;
all_img = np.float32(np.zeros((file_num, 224, 224, 3))) 
all_label = np.float64(np.zeros((file_num, 1)))
 
for img_name in file_list1:
    img_path = path_dir1+img_name
    img = load_img(img_path, target_size=(224, 224))
    
    x = img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    all_img[num, :, :, :] = x
    
    all_label[num] = 0 # nomask
    num = num + 1

for img_name in file_list2:
    img_path = path_dir2+img_name
    img = load_img(img_path, target_size=(224, 224))
    
    x = img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    all_img[num, :, :, :] = x
    
    all_label[num] = 1 # mask
    num = num + 1
 
 
# mengacak kumpulan data (untuk memastikan pelatihan yang tepat)
n_elem = all_label.shape[0]
indices = np.random.choice(n_elem, size=n_elem, replace=False)
 
all_label = all_label[indices]
all_img = all_img[indices]
 
# memisahkan set pelatihan dan data test
num_train = int(np.round(all_label.shape[0]*0.8))
num_test = int(np.round(all_label.shape[0]*0.2))
 
train_img = all_img[0:num_train, :, :, :]
test_img = all_img[num_train:, :, :, :] 
 
train_label = all_label[0:num_train]
test_label = all_label[num_train:]
 
 
 
# membuat model dasar yang telah dilatih
IMG_SHAPE = (224, 224, 3)
 
base_model = ResNet50(input_shape=IMG_SHAPE, weights='imagenet', include_top=False)
base_model.trainable = False
base_model.summary()
print("Number of layers in the base model: ", len(base_model.layers))
 
flatten_layer = Flatten()
dense_layer1 = Dense(128, activation='relu')
bn_layer1 = BatchNormalization()
dense_layer2 = Dense(1, activation=tf.nn.sigmoid)
 
model = Sequential([
        base_model,
        flatten_layer,
        dense_layer1,
        bn_layer1,
        dense_layer2,
        ])
 
base_learning_rate = 0.001
model.compile(optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate),
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
 
history = model.fit(train_img, train_label, epochs=10, batch_size=16, validation_data = (test_img, test_label))
 
# save model
model.save("model.h5")
 
print("Saved model to disk")
# Out:
# C:\Users\relax\miniconda3\envs\LatihanCV\lib\site-packages\PIL\Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_3[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 0
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________
# Number of layers in the base model:  175
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten_2 (Flatten)         (None, 100352)            0
#
#  dense_4 (Dense)             (None, 128)               12845184
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 36,433,537
# Trainable params: 12,845,569
# Non-trainable params: 23,587,968
# _________________________________________________________________
# Epoch 1/10
# C:\Users\relax\miniconda3\envs\LatihanCV\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 27/27 [==============================] - 38s 1s/step - loss: 0.2829 - accuracy: 0.9336 - val_loss: 1.2477 - val_accuracy: 0.8762
# Epoch 2/10
# 27/27 [==============================] - 29s 1s/step - loss: 0.0291 - accuracy: 0.9929 - val_loss: 0.5611 - val_accuracy: 0.8952
# Epoch 3/10
# 27/27 [==============================] - 30s 1s/step - loss: 0.0270 - accuracy: 0.9929 - val_loss: 0.3914 - val_accuracy: 0.9048
# Epoch 4/10
# 27/27 [==============================] - 31s 1s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2913 - val_accuracy: 0.9143
# Epoch 5/10
# 27/27 [==============================] - 30s 1s/step - loss: 0.0064 - accuracy: 0.9976 - val_loss: 0.2292 - val_accuracy: 0.9333
# Epoch 6/10
# 27/27 [==============================] - 30s 1s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1849 - val_accuracy: 0.9333
# Epoch 7/10
# 27/27 [==============================] - 30s 1s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1771 - val_accuracy: 0.9333
# Epoch 8/10
# 27/27 [==============================] - 33s 1s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1813 - val_accuracy: 0.9333
# Epoch 9/10
# 27/27 [==============================] - 32s 1s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1795 - val_accuracy: 0.9333
# Epoch 10/10
# 27/27 [==============================] - 31s 1s/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.1736 - val_accuracy: 0.9333
# Saved model to disk

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'go', label='Training Loss')
plt.plot(epochs, val_loss, 'g', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

# Plotting accuracy
plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')

# Plotting loss
plt.plot(epochs, loss, 'go', label='Training Loss')
plt.plot(epochs, val_loss, 'g', label='Validation Loss')

plt.title('Training and Validation Metrics')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %%
print("Prediction:", prediction)
print("Raw Predictions:", prediction)
# Out:
# Prediction: [[0.02891449]]
# Raw Predictions: [[0.02891449]]

# %%
import cvlib as cv
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array

model = load_model('C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\model.h5')
model.summary()

# membuka webcam
webcam = cv2.VideoCapture(0)

if not webcam.isOpened():
    print("Could not open webcam")
    exit()

# loop frames
while webcam.isOpened():
    # membaca frame dari webcam
    status, frame = webcam.read()

    if not status:
        print("Could not read frame")
        exit()

    # deteksi
    face, confidence = cv.detect_face(frame)

    # loop melalui wajah yang terdeteksi
    for idx, f in enumerate(face):
        (startX, startY) = f[0], f[1]
        (endX, endY) = f[2], f[3]

        if 0 <= startX <= frame.shape[1] and 0 <= endX <= frame.shape[1] and 0 <= startY <= frame.shape[0] and 0 <= endY <= frame.shape[0]:
            face_region = frame[startY:endY, startX:endX]
            face_region1 = cv2.resize(face_region, (224, 224), interpolation=cv2.INTER_AREA)

            x = img_to_array(face_region1)
            x = np.expand_dims(x, axis=0)
            x = preprocess_input(x)

            prediction = model.predict(x)
            threshold = 0.01

            if prediction < threshold:  # Helmet X
                cv2.rectangle(frame, (startX, startY), (endX, endY), (0, 0, 255), 2)
                Y = startY - 10 if startY - 10 > 10 else startY + 10
                text = "Helmet X"
                cv2.putText(frame, text, (startX, Y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

            else:  # Helmet O
                cv2.rectangle(frame, (startX, startY), (endX, endY), (0, 255, 0), 2)
                Y = startY - 10 if startY - 10 > 10 else startY + 10
                text = "Helmet O"
                cv2.putText(frame, text, (startX, Y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

    # output
    cv2.imshow("Helmet classify", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

webcam.release()
cv2.destroyAllWindows()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten_2 (Flatten)         (None, 100352)            0
#
#  dense_4 (Dense)             (None, 128)               12845184
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 36,433,537
# Trainable params: 12,845,569
# Non-trainable params: 23,587,968
# _________________________________________________________________
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 114ms/step

# %%
print("Prediction:", prediction)
print("Raw Predictions:", prediction)
# Out:
# Prediction: [[0.00098872]]
# Raw Predictions: [[0.00098872]]

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from cvlib import detect_face

model = load_model('C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\model.h5')
model.summary()

video_path = input("Enter the video file path: ")

cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        print("Error: Could not read frame.")
        break

    faces, confidences = detect_face(frame)

    for idx, (startX, startY, endX, endY) in enumerate(faces):
        face_region = frame[startY:endY, startX:endX]

        face_region_resized = cv2.resize(face_region, (224, 224), interpolation=cv2.INTER_AREA)
        x = img_to_array(face_region_resized)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)

        predictions = model.predict(x)

        print("Predictions:", predictions)
        print("Confidence Scores:", confidences[idx])

        threshold = 0.1  # threshold
        helmet_detected = predictions[0] > threshold
        if helmet_detected:
            helmet_label = "Helmet O"
            helmet_color = (0, 255, 0)
        else:
            helmet_label = "Helmet X"
            helmet_color = (0, 0, 255)


        cv2.rectangle(frame, (startX, startY), (endX, endY), helmet_color, 2)
        Y = startY - 10 if startY - 10 > 10 else startY + 10
        cv2.putText(frame, helmet_label, (startX, Y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, helmet_color, 2)

    cv2.imshow("Face and Helmet Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten_2 (Flatten)         (None, 100352)            0
#
#  dense_4 (Dense)             (None, 128)               12845184
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 36,433,537
# Trainable params: 12,845,569
# Non-trainable params: 23,587,968
# _________________________________________________________________
# Enter the video file path: C:\Users\relax\miniconda3\envs\LatihanCV\helm\helm\dataset\rysel.mp4
# 1/1 [==============================] - 1s 1s/step
# Predictions: [[0.8601167]]
# Confidence Scores: 0.9934681
# 1/1 [==============================] - 0s 130ms/step
# Predictions: [[0.8601167]]
# Confidence Scores: 0.9934681
# 1/1 [==============================] - 0s 136ms/step
# Predictions: [[0.8410434]]
# Confidence Scores: 0.9938028
# 1/1 [==============================] - 0s 130ms/step
# Predictions: [[0.9447656]]
# Confidence Scores: 0.9920223
# 1/1 [==============================] - 0s 129ms/step
# Predictions: [[0.9145699]]
# Confidence Scores: 0.9926658
# 1/1 [==============================] - 0s 130ms/step
# Predictions: [[0.93381536]]
# Confidence Scores: 0.99252266
# 1/1 [==============================] - 0s 129ms/step
# Predictions: [[0.9004453]]
# Confidence Scores: 0.9935628
# 1/1 [==============================] - 0s 125ms/step
# Predictions: [[0.8310935]]
# Confidence Scores: 0.9927226
# 1/1 [==============================] - 0s 135ms/step
# Predictions: [[0.95404196]]
# Confidence Scores: 0.98367333
# 1/1 [==============================] - 0s 127ms/step
# Predictions: [[0.9468196]]
# Confidence Scores: 0.9826586
# 1/1 [==============================] - 0s 125ms/step
# Predictions: [[0.94787514]]
# Confidence Scores: 0.9795632
# 1/1 [==============================] - 0s 124ms/step
# Predictions: [[0.7742284]]
# Confidence Scores: 0.9933054
# 1/1 [==============================] - 0s 126ms/step
# Predictions: [[0.8372143]]
# Confidence Scores: 0.9942087
# 1/1 [==============================] - 0s 124ms/step
# Predictions: [[0.82259864]]
# Confidence Scores: 0.9939115
# 1/1 [==============================] - 0s 122ms/step
# Predictions: [[0.9285564]]
# Confidence Scores: 0.9895465
# 1/1 [==============================] - 0s 127ms/step
# Predictions: [[0.952079]]
# Confidence Scores: 0.99139905
# 1/1 [==============================] - 0s 123ms/step
# Predictions: [[0.9358738]]
# Confidence Scores: 0.9686004
# 1/1 [==============================] - 0s 129ms/step
# Predictions: [[0.9582318]]
# Confidence Scores: 0.97846895
# 1/1 [==============================] - 0s 136ms/step
# Predictions: [[0.96837175]]
# Confidence Scores: 0.95761144
# 1/1 [==============================] - 0s 126ms/step
# Predictions: [[0.9409869]]
# Confidence Scores: 0.9663901
# 1/1 [==============================] - 0s 130ms/step
# Predictions: [[0.94821775]]
# Confidence Scores: 0.9442484
# 1/1 [==============================] - 0s 131ms/step
# Predictions: [[0.90250427]]
# Confidence Scores: 0.9310926
# 1/1 [==============================] - 0s 141ms/step
# Predictions: [[0.76197326]]
# Confidence Scores: 0.93554026
# 1/1 [==============================] - 0s 128ms/step
# Predictions: [[0.86734176]]
# Confidence Scores: 0.9697748
# 1/1 [==============================] - 0s 125ms/step
# Predictions: [[0.79501045]]
# Confidence Scores: 0.91945225
# 1/1 [==============================] - 0s 127ms/step
# Predictions: [[0.90097976]]
# Confidence Scores: 0.9287911
# 1/1 [==============================] - 0s 122ms/step
# Predictions: [[0.8661774]]
# Confidence Scores: 0.9862264
# 1/1 [==============================] - 0s 132ms/step
# Predictions: [[0.86219174]]
# Confidence Scores: 0.9822808
# 1/1 [==============================] - 0s 130ms/step
# Predictions: [[0.617437]]
# Confidence Scores: 0.9575136
# 1/1 [==============================] - 0s 152ms/step
# Predictions: [[0.6754949]]
# Confidence Scores: 0.96281075
# 1/1 [==============================] - 0s 126ms/step
# Predictions: [[0.45536828]]
# Confidence Scores: 0.9591043
# 1/1 [==============================] - 0s 124ms/step
# Predictions: [[0.6553994]]
# Confidence Scores: 0.95066243
# 1/1 [==============================] - 0s 131ms/step
# Predictions: [[0.61217904]]
# Confidence Scores: 0.96602136
# 1/1 [==============================] - 0s 135ms/step
# Predictions: [[0.6077873]]
# Confidence Scores: 0.9820493
# 1/1 [==============================] - 0s 128ms/step
# Predictions: [[0.84021086]]
# Confidence Scores: 0.97735846
# 1/1 [==============================] - 0s 161ms/step
# Predictions: [[0.9279906]]
# Confidence Scores: 0.98212117
# 1/1 [==============================] - 0s 128ms/step
# Predictions: [[0.77701765]]
# Confidence Scores: 0.96405536
# 1/1 [==============================] - 0s 132ms/step
# Predictions: [[0.94487005]]
# Confidence Scores: 0.96603984
# 1/1 [==============================] - 0s 128ms/step
# Predictions: [[0.960687]]
# Confidence Scores: 0.9203719
# 1/1 [==============================] - 0s 131ms/step
# Predictions: [[0.9630378]]
# Confidence Scores: 0.73522186
# 1/1 [==============================] - 0s 127ms/step
# Predictions: [[0.95765483]]
# Confidence Scores: 0.84368855
# 1/1 [==============================] - 0s 166ms/step
# Predictions: [[0.9031126]]
# Confidence Scores: 0.90410274
# 1/1 [==============================] - 0s 129ms/step
# Predictions: [[0.95930326]]
# Confidence Scores: 0.93664545
# 1/1 [==============================] - 0s 129ms/step
# Predictions: [[0.9872347]]
# Confidence Scores: 0.9470621
# 1/1 [==============================] - 0s 130ms/step
# Predictions: [[0.9853216]]
# Confidence Scores: 0.8875412
# 1/1 [==============================] - 0s 128ms/step
# Predictions: [[0.9850695]]
# Confidence Scores: 0.6964264
# 1/1 [==============================] - 0s 131ms/step
# Predictions: [[0.98332334]]
# Confidence Scores: 0.7328794
# 1/1 [==============================] - 0s 125ms/step
# Predictions: [[0.97353846]]
# Confidence Scores: 0.64334977
# 1/1 [==============================] - 0s 133ms/step
# Predictions: [[0.99501723]]
# Confidence Scores: 0.68409854
# 1/1 [==============================] - 0s 155ms/step
# Predictions: [[0.7905564]]
# Confidence Scores: 0.57038015
# 1/1 [==============================] - 0s 132ms/step
# Predictions: [[0.8751453]]
# Confidence Scores: 0.8180919
# 1/1 [==============================] - 0s 131ms/step
# Predictions: [[0.8307897]]
# Confidence Scores: 0.66326237
# 1/1 [==============================] - 0s 133ms/step
# Predictions: [[0.91098374]]
# Confidence Scores: 0.6453752
# 1/1 [==============================] - 0s 143ms/step
# Predictions: [[0.9721681]]
# Confidence Scores: 0.5311549
# 1/1 [==============================] - 0s 130ms/step
# Predictions: [[0.974889]]
# Confidence Scores: 0.56274265
# 1/1 [==============================] - 0s 127ms/step
# Predictions: [[0.94610316]]
# Confidence Scores: 0.67320836
# 1/1 [==============================] - 0s 150ms/step
# Predictions: [[0.98360157]]
# Confidence Scores: 0.9345415
# 1/1 [==============================] - 0s 231ms/step
# Predictions: [[0.9031622]]
# Confidence Scores: 0.974481
# 1/1 [==============================] - 0s 199ms/step
# Predictions: [[0.97755766]]
# Confidence Scores: 0.9748805
# 1/1 [==============================] - 0s 179ms/step
# Predictions: [[0.97716427]]
# Confidence Scores: 0.60443807
# 1/1 [==============================] - 0s 171ms/step
# Predictions: [[0.9282993]]
# Confidence Scores: 0.74897915
# 1/1 [==============================] - 0s 159ms/step
# Predictions: [[0.99059683]]
# Confidence Scores: 0.68782955
# 1/1 [==============================] - 0s 168ms/step
# Predictions: [[0.99533105]]
# Confidence Scores: 0.848095
# 1/1 [==============================] - 0s 151ms/step
# Predictions: [[0.79964244]]
# Confidence Scores: 0.7282974
# 1/1 [==============================] - 0s 186ms/step
# Predictions: [[0.85011697]]
# Confidence Scores: 0.7670636
# 1/1 [==============================] - 0s 156ms/step
# Predictions: [[0.882939]]
# Confidence Scores: 0.68009794
# 1/1 [==============================] - 0s 148ms/step
# Predictions: [[0.94534105]]
# Confidence Scores: 0.50074804
# 1/1 [==============================] - 0s 154ms/step
# Predictions: [[0.9667634]]
# Confidence Scores: 0.74051636
# 1/1 [==============================] - 0s 141ms/step
# Predictions: [[0.9891733]]
# Confidence Scores: 0.6528285
# 1/1 [==============================] - 0s 145ms/step
# Predictions: [[0.95176667]]
# Confidence Scores: 0.7152215
# 1/1 [==============================] - 0s 141ms/step
# Predictions: [[0.9237451]]
# Confidence Scores: 0.86397046
# 1/1 [==============================] - 0s 139ms/step
# Predictions: [[0.7845183]]
# Confidence Scores: 0.782492
# 1/1 [==============================] - 0s 138ms/step
# Predictions: [[0.7086615]]
# Confidence Scores: 0.65460485
# 1/1 [==============================] - 0s 153ms/step
# Predictions: [[0.4076187]]
# Confidence Scores: 0.57634944
# 1/1 [==============================] - 0s 156ms/step
# Predictions: [[0.5851436]]
# Confidence Scores: 0.651964
# 1/1 [==============================] - 0s 150ms/step
# Predictions: [[0.42615753]]
# Confidence Scores: 0.5008167
# 1/1 [==============================] - 0s 155ms/step
# Predictions: [[0.73308563]]
# Confidence Scores: 0.5551683
# 1/1 [==============================] - 0s 147ms/step
# Predictions: [[0.5378836]]
# Confidence Scores: 0.73914415
# 1/1 [==============================] - 0s 157ms/step
# Predictions: [[0.83415896]]
# Confidence Scores: 0.9073419
# 1/1 [==============================] - 0s 157ms/step
# Predictions: [[0.83455634]]
# Confidence Scores: 0.83032686
# 1/1 [==============================] - 0s 183ms/step
# Predictions: [[0.8028061]]
# Confidence Scores: 0.86643654
# 1/1 [==============================] - 0s 175ms/step
# Predictions: [[0.5550299]]
# Confidence Scores: 0.8881509
# 1/1 [==============================] - 0s 177ms/step
# Predictions: [[0.73073685]]
# Confidence Scores: 0.6315267
# 1/1 [==============================] - 0s 128ms/step
# Predictions: [[0.8612888]]
# Confidence Scores: 0.50940096
# 1/1 [==============================] - 0s 124ms/step
# Predictions: [[0.3207275]]
# Confidence Scores: 0.60591805
# 1/1 [==============================] - 0s 127ms/step
# Predictions: [[0.2987684]]
# Confidence Scores: 0.60662115
# 1/1 [==============================] - 0s 132ms/step
# Predictions: [[0.4910427]]
# Confidence Scores: 0.60093814
# 1/1 [==============================] - 0s 128ms/step
# Predictions: [[0.00670084]]
# Confidence Scores: 0.5943953
# 1/1 [==============================] - 0s 125ms/step
# Predictions: [[0.11428738]]
# Confidence Scores: 0.56746805
# 1/1 [==============================] - 0s 128ms/step
# Predictions: [[0.11809196]]
# Confidence Scores: 0.51188487
# 1/1 [==============================] - 0s 120ms/step
# Predictions: [[0.02272993]]
# Confidence Scores: 0.55337983
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[64], line 31
#      28 for idx, (startX, startY, endX, endY) in enumerate(faces):
#      29     face_region = frame[startY:endY, startX:endX]
# ---> 31     face_region_resized = cv2.resize(face_region, (224, 224), interpolation=cv2.INTER_AREA)
#      32     x = img_to_array(face_region_resized)
#      33     x = np.expand_dims(x, axis=0)
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
predictions = model.predict(x)
print("Predictions:", predictions)
# Out:
# 1/1 [==============================] - 0s 108ms/step
# Predictions: [[0.02529226]]

# %%
img = cv2.imread('C:\\Users\\relax\\miniconda3\\envs\\LatihanCV\\ResNet50-HelmDetection\\dataset\\helmet_yes\\helmety52.jpg')  # Replace with an actual image path
face_region_resized = cv2.resize(img, (224, 224), interpolation=cv2.INTER_AREA)
x = img_to_array(face_region_resized)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
predictions = model.predict(x)
print("Predictions:", predictions)
# Out:
# 1/1 [==============================] - 0s 120ms/step
# Predictions: [[0.9999986]]
